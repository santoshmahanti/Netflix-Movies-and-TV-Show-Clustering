# %% [markdown]
# <a href="https://colab.research.google.com/github/santoshmahanti/Netflix-Movies-and-TV-Show-Clustering/blob/main/Netflix_Movies_and_TV_Show_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Netflix Movies and TV Show clustering

# %% [markdown]
# ##### **Project Type**    - Unsupervised
# ##### **Contribution**    - Team
# ##### **Team Member 1 -** Bhaskar Kumar
# ##### **Team Member 2 -** Santosh Mahanati

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This dataset consists of tv shows and movies available on Netflix as of 2019. The dataset is collected from Flixable which is a third-party Netflix search engine.
# In 2018, they released an interesting report which shows that the number of TV shows on Netflix has nearly tripled since 2010. The streaming service’s number of movies has decreased by more than 2,000 titles since 2010, while its number of TV shows has nearly tripled. It will be interesting to explore what all other insights can be obtained from the same dataset.
#
# Integrating this dataset with other external datasets such as IMDB ratings, rotten tomatoes can also provide many interesting findings.
#
# In this project, you are required to do
#
#
# *   Exploratory Data Analysis
#
# *   Understanding what type content is available in different countries
#
# *   If Netflix has been increasingly focusing on TV rather than movies in recent years.
#
# *   Clustering similar content by matching text-based features
#
#
# ![Unsupervised_ML_Netflix_Movies_and_TV_Shows_Clustering_ce34d02ec9.png](data:image/png;base64,...)

# %% [markdown]
# **Follwing are the descriptions for different ratings in data:**
#
# 1. TV-MA: This rating stands for "Mature Audiences Only" and indicates that the content of a TV show is intended for adults and may contain mature themes, language, violence, and sexual content.
#
# 2. R: This rating is assigned by the Motion Picture Association of America (MPAA) and indicates that the content of a movie is intended for adults and may contain strong language, violence, nudity, and sexual content.
#
# 3. PG-13: This rating is assigned by the MPAA and indicates that the content of a movie may be inappropriate for children under 13 and may contain violence, language, and sexual content.
#
# 4. TV-14: This rating indicates that the content of a TV show is intended for older teens and may contain mature themes, language, violence, and sexual content.
#
# 5. TV-PG: This rating indicates that the content of a TV show may be inappropriate for children and may contain mature themes, language, and violence.
#
# 6. NR: This rating stands for "Not Rated" and means that a movie or TV show has not been officially rated by the MPAA or the TV Parental Guidelines.
#
# 7. TV-G: This rating indicates that the content of a TV show is suitable for all audiences and contains little or no violence, sexual content, or mature themes.
#
# 8. TV-Y: This rating indicates that the content of a TV show is suitable for young children and contains little or no violence, sexual content, or mature themes.
#
# 9. NaN: NaN stands for "Not a Number" and is a special value that represents missing or undefined data.
#
# 10. TV-Y7: This rating indicates that the content of a TV show is intended for children 7 years and older and may contain fantasy violence.
#
# 11. PG: This rating is assigned by the MPAA and indicates that the content of a movie may be inappropriate for children and may contain violence, language, and sexual content.
#
# 12. G: This rating stands for General Audiences. This rating is assigned to movies and TV shows that are suitable for all audiences and contains little or no violence, sexual content, or mature themes.
#
# 13. NC-17: This rating is assigned by the MPAA and indicates that the content of a movie is intended for adults only and may contain explicit sexual content and violence.
#
# 14. TV-Y7-FV: This rating indicates that the content of a TV show is intended for children 7 years and older and may contain fantasy violence.
#
# 15. UR: This rating stands for "Unrated" and means that a movie or TV show has not been officially rated by the MPAA or the TV Parental Guidelines.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import datetime

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/NETFLIX MOVIES AND TV SHOWS CLUSTERING/Data/NETFLIX MOVIES AND TV SHOWS CLUSTERING.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (7787, 12)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
# Visualizing the missing values
# setting configuration for our plots
plt.rcParams['figure.figsize'] = (15, 5)

sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.xlabel('Column Names')
plt.ylabel('NullValues in yellow shadow.')
# Out:
# Text(131.0, 0.5, 'NullValues in yellow shadow.')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *   There are 7787 rows and 12 columns.
# *   director, cast, country, date_added columns had null values, with director column having maximum 2389 null values in it.
# *   There is no duplication of rows in data.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#        show_id   type title                director                cast  \
# count     7787   7787  7787                    5398                7069
# unique    7787      2  7787                    4049                6831
# top         s1  Movie    3%  Raúl Campos, Jan Suter  David Attenborough
# freq         1   5377     1                      18                  18
# mean       NaN    NaN   NaN                     NaN                 NaN
# std        NaN    NaN   NaN                     NaN                 NaN
# min        NaN    NaN   NaN                     NaN                 NaN
# 25%        NaN    NaN   NaN                     NaN                 NaN
# 50%        NaN    NaN   NaN                     NaN                 NaN
# 75%        NaN    NaN   NaN                     NaN                 NaN
# max        NaN    NaN   NaN                     NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            7280             7777   7787.000000   7780      7787
# unique            681             1565           NaN     14       216
# top     United States  January 1, 2020           NaN  TV-MA  1 Season
# freq             2555              118           NaN   2863      1608
# mean              NaN              NaN   2013.932580    NaN       NaN
# std               NaN              NaN      8.757395    NaN       NaN
# min               NaN              NaN   1925.000000    NaN       NaN
# 25%               NaN              NaN   2013.000000    NaN       NaN
# 50%               NaN              NaN   2017.000000    NaN       NaN
# 75%               NaN              NaN   2018.000000    NaN       NaN
# max               NaN              NaN   2021.000000    NaN       NaN
#
#             listed_in                                        description
# count            7787                                               7787
# unique            492                                               7769
# top     Documentaries  Multiple women report their husbands as missin...
# freq              334                                                  3
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Most of the columns, i.e, variables, in the data have text data, with only release_year column being int column.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# show_id         7787
# type               2
# title           7787
# director        4049
# cast            6831
# country          681
# date_added      1565
# release_year      73
# rating            14
# duration         216
# listed_in        492
# description     7769
# dtype: int64

# %% [markdown]
# Most of the variables have large number of unique values. Except for columns "type" and "rating"

# %%
# finding unique values in type column
df['type'].unique()
# Out:
# array(['TV Show', 'Movie'], dtype=object)

# %%
# finding unique values in rating column
df['rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# unique values in director column
df['director'].unique()
# Out:
# array([nan, 'Jorge Michel Grau', 'Gilbert Chan', ..., 'Josef Fares',
#        'Mozez Singh', 'Sam Dunn'], dtype=object)

# %%
# getting value counts for each listed_in category
df['listed_in'].value_counts()
# Out:
# Documentaries                                                                      334
# Stand-Up Comedy                                                                    321
# Dramas, International Movies                                                       320
# Comedies, Dramas, International Movies                                             243
# Dramas, Independent Movies, International Movies                                   215
#                                                                                   ...
# Crime TV Shows, Romantic TV Shows, Spanish-Language TV Shows                         1
# Crime TV Shows, International TV Shows, Reality TV                                   1
# International Movies, Romantic Movies, Sci-Fi & Fantasy                              1
# Stand-Up Comedy & Talk Shows, TV Mysteries, TV Sci-Fi & Fantasy                      1
# International TV Shows, Spanish-Language TV Shows, Stand-Up Comedy & Talk Shows      1
# Name: listed_in, Length: 492, dtype: int64

# %% [markdown]
# documentaries is the most listed category in data, followed by Stand-Up comedy, and Dramas, International Movies. Although, this can change if looked at individual genres like 'comedy' or 'international movies' if they will occurr much frequntly accross datset.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Converting date_added column from string to datetime format
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
#checking date_added column
df["date_added"]
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7782   2020-10-19
# 7783   2019-03-02
# 7784   2020-09-25
# 7785   2020-10-31
# 7786   2020-03-01
# Name: date_added, Length: 7787, dtype: datetime64[ns]

# %% [markdown]
# ### What is the range of dates for date_added column.

# %%
# getting range of dates from date_added column
earliest_date = str(min(df["date_added"]).date())

last_date = str(max(df['date_added']).date())

print(f'Movies in the dataset were added from {earliest_date} to {last_date}')
# Out:
# Movies in the dataset were added from 2008-01-01 to 2021-01-16

# %% [markdown]
# ### Getting list of all directors in dataset

# %%
# getting a list of all directors in entire dataset
directors_list = []

# iterating through each row in datset where director column does not have a null value
for i in df[~df['director'].isna()]['director']:
  directors_list.append(i)

#printing total number of directors 
print(f'There were a total of {len(directors_list)} directors in the dataset overall.')
# Out:
# There were a total of 5398 directors in the dataset overall.

# %% [markdown]
# As some columns have more than one category in its row value. I am creating two functions to get list of all unique categories across dataset and get key for most frequently occuring category in the dataset.

# %%
# creating a function to get list of categories mentioned in all of rows
def get_category_list(column):
  cat_list = []
  
  # iterating through each row in column to get a list of all individual names listed there
  for i in column:
    if "," in i:
      m = i.split(",")
      cat_list.extend(m)
    else:
      cat_list.append(i)

  # getting unique names
  cat_list = list(set(cat_list))

  return cat_list

# %%
# creating a function to get most frequently occuring category
from collections import Counter

def maximum_occuring_category(column, list_):
    # creating an empty dict to store frequency if each category in dataset
    cat_freq_dict = Counter()

    #iterating through each column to find list of categories from each row
    for i in column:
        # creating a local list to store category list splitted by ","
        m= []
        if "," in i:
            m.extend(i.split(","))
        else:
            m.append(i)
        #iterating through cat_list to check if category exists in particular row 
        for j in range(len(list_)):
            if list_[j] in m:
                cat_freq_dict[list_[j]] += 1
            else:
                pass
    if not cat_freq_dict:
        return None
    return cat_freq_dict.most_common(1)[0][0]

# %% [markdown]
# Getting number of all casts in tv shows and movies.

# %%
# getting list of total cast in datset
# creating an empty list
total_cast_list = []

# appending total cast list to get cast from df where cast is not 'Nan'
total_cast_list.extend(get_category_list(df[~df['cast'].isna()]['cast']))

print(f'A total of {len(total_cast_list)} cast have worked in all of the tv shows and movies in dataset, whoosh!')
# Out:
# A total of 35372 cast have worked in all of the tv shows and movies in dataset, whoosh!

# %% [markdown]
# Actor which have done maximum number of movies or tv shows

# %%
# actors who have worked in most number of movies or tv shows
most_freq_accouring_cast = maximum_occuring_category(df[~df['cast'].isna()]['cast'], total_cast_list)

print(f'{most_freq_accouring_cast} has worked in maximum number of TV Shows or Movies in entire dataset.')
# Out:
#  Anupam Kher has worked in maximum number of TV Shows or Movies in entire dataset.

# %% [markdown]
# Total number of genres

# %%
# getting list of categories from listed_in column
genre_list = []
genre_list.extend(get_category_list(df['listed_in']))

# printing total number of categories in database
print('Total number of categories/genres in database are:' ,len(genre_list))
# Out:
# Total number of categories/genres in database are: 73

# %% [markdown]
# Most frequently occuring genre overall.

# %%
# finding which genre is most common across entire dataset
most_freq_accouring_genre = maximum_occuring_category(df['listed_in'], genre_list)

print(f'Most frequently occuring genre in dataset is {most_freq_accouring_genre}')
# Out:
# Most frequently occuring genre in dataset is  International Movies

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# getting number of movies and tv shows in dataset
df['type'].value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: type, dtype: int64

# %% [markdown]
# ### One can see that there are 5377 movies in dataset while there are 2410 TV shows overall.

# %%
# getting number of content by each rating type
rating_dict = dict(df['rating'].value_counts())

# getting percentage of each type of content in data
for i,j in rating_dict.items():
  print(f'Percentage of {i} rating content in dataset is {round((j/df.shape[0])*100,2)}%')
  print('-'*150)
# Out:
# Percentage of TV-MA rating content in dataset is 36.77%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of TV-14 rating content in dataset is 24.8%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of TV-PG rating content in dataset is 10.35%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of R rating content in dataset is 8.54%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of PG-13 rating content in dataset is 4.96%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of TV-Y rating content in dataset is 3.6%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of TV-Y7 rating content in dataset is 3.48%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of PG rating content in dataset is 3.17%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of TV-G rating content in dataset is 2.49%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of NR rating content in dataset is 1.08%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of G rating content in dataset is 0.5%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of TV-Y7-FV rating content in dataset is 0.08%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of UR rating content in dataset is 0.06%
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Percentage of NC-17 rating content in dataset is 0.04%
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Most of the content in the dataset have adult rating.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# *  I converted date_added column from string to datetime column for the ease of sorting.
# *  I found that all the content in the dataset were added from 2008-01-01 to 2021-01-16.
# *  A total of 35372 cast members have worked in all of the tv shows and movies in dataset.
# *  There were a total of 5398 directors in the dataset overall.
# *  Anupam Kher has worked in maximum number of TV Shows or Movies in entire dataset.
# *  Total number of categories/genres in database are 73.
# *  Most frequently occuring genre in dataset is  International Movies.
# *  There are 5377 movies in dataset while there are 2410 TV shows overall.
# *  Most of the content in the dataset have adult ratings.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Chart - 1 (**Pie Chart Showing Share of Movies and TV-Shows in data**)

# %%
# Chart - 1 visualization code
plt.figure(figsize=(10,8))
# define Seaborn color palette to use
palette_color = sns.color_palette('inferno')

# plotting data on chart
plt.pie(df['type'].value_counts(), labels=list(df['type'].value_counts().index), colors=palette_color, autopct='%.0f%%')

plt.title('Pie chart showing percentage share of Movies and TV-Shows in Dataset', fontsize = 20)
# displaying chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked pie chart because it is easier to show percentage share of Movies and TV-Shows on it. As, it is easier to represent how much share of pie does each one of them contains, here, this pie is our entire dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Movies contain maximum share of content in data with 69% of entire content being movies, and TV Shows comprises of 31% of all contents.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2 (**Top 10 directors who have directed maximum number of movies**)

# %%
# creating a saperate movie df for all movies in data_set
movie_df = df[df['type']=="Movie"]

# creating a df containg top 10 tv show directors
top_10_director_df = movie_df['director'].value_counts().head(10).reset_index().rename(columns={'index':'director', 'director':'number_of_movies'})

# %%
# Chart - 2 visualization code
# setting style for seaborn plot
sns.set_style('whitegrid')

# setting figuresize
plt.figure(figsize=(18,6))

# creating barplot
sns.barplot(data=top_10_director_df, x='director', y='number_of_movies')

#setting title
plt.title('Top 10 Directors who have directed maximum number of movies', fontsize=20)
plt.xlabel('Directors', fontsize=12)
plt.ylabel('Number of movies directed', fontsize=10)

# setting xticklabels to 45
plt.xticks(rotation=15)

plt.show()

# %% [markdown]
# Some of the movies directed by Raul Campus and Jan Suter are:

# %%
for i in movie_df[movie_df['director']=='Raúl Campos, Jan Suter']['title']:
  print(i)
  print('-'*50)
# Out:
# Alan Saldaña: Mi vida de pobre
# --------------------------------------------------
# Arango y Sanint: Ríase el show
# --------------------------------------------------
# Carlos Ballarta: Furia Ñera
# --------------------------------------------------
# Coco y Raulito: Carrusel de ternura
# --------------------------------------------------
# Daniel Sosa: Sosafado
# --------------------------------------------------
# Fernando Sanjiao: Hombre
# --------------------------------------------------
# Jani Dueñas: Grandes fracasos de ayer y hoy
# --------------------------------------------------
# Luciano Mellera: Infantiloide
# --------------------------------------------------
# Malena Pichot: Estupidez compleja
# --------------------------------------------------
# Mea Culpa
# --------------------------------------------------
# Natalia Valdebenito: El especial
# --------------------------------------------------
# Ricardo O'Farrill Abrazo Genial
# --------------------------------------------------
# Ricardo O'Farrill: Abrazo navideño
# --------------------------------------------------
# Ricardo Quevedo: Hay gente así
# --------------------------------------------------
# Sebastián Marcelo Wainraich
# --------------------------------------------------
# Sofía Niño de Rivera: Exposed
# --------------------------------------------------
# Sofía Niño de Rivera: Selección Natural
# --------------------------------------------------
# Todo lo que sería Lucas Lauriente
# --------------------------------------------------

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart to show top 10 directors who have directed maximum number of movies out of all movies in dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Raul Campus and Jan Suter have together directed maximum number of movies than any other director in the entire dataset.
#
# * He was followed by Marcus Raboy, Jay Karas, Cathy Garcia-Molina and others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3 (**Top 10 directors who have directed maximum number of TV Shows**)

# %%
# creating a saperate movie df for all movies in data_set
tv_show_df = df[df['type']=="TV Show"]

# creating a df containg top 10 tv show directors
top_10_tv_director_df = tv_show_df['director'].value_counts().head(10).reset_index().rename(columns={'index':'director', 'director':'number_of_tv_shows'})

# %%
# Chart - 3 visualization code
# creating barplot
sns.barplot(data=top_10_tv_director_df, x='director', y='number_of_tv_shows')

#setting title
plt.title('Top 10 Directors who have directed maximum number of TV Shows', fontsize=20)
plt.xlabel('Directors', fontsize=12)
plt.ylabel('Number of TV Show directed', fontsize=10)

# setting xticklabels to 45
plt.xticks(rotation=15)

plt.show()

# %% [markdown]
# Some of the movies directed by Alastair Fothergill

# %%
for k in tv_show_df[tv_show_df['director']=='Alastair Fothergill']['title']:
  print(k)
  print('-'*50)
# Out:
# Frozen Planet
# --------------------------------------------------
# Planet Earth: The Complete Collection
# --------------------------------------------------
# The Blue Planet: A Natural History of the Oceans
# --------------------------------------------------

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart to show list of directors who have directed maxmimum number of TV Shows.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Alastair Fothergill has directed maximum number of TV Shows in the dataset overall. He is followed by Ken Burns, Shin-Won-ho, Iginio Straffi and more.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4  (**Actors who have acted in maximum number of movies**)

# %% [markdown]
# Following is a function to get top 10 maximum occuring category or name from a column.

# %%
# creating a functions to return most frequently occuring categories or names in a column
def top_10_maximum_occuring(column):
    # creating an empty dict to store frequency if each category in dataset
    cat_freq_dict = Counter()

    # creating a list of all categories in column with function get_category_list
    list_ = get_category_list(column)

    #iterating through each column to find list of categories from each row
    for i in column:
        # creating a local list to store category list splitted by ","
        m= []
        if "," in i:
            m.extend(i.split(","))
        else:
            m.append(i)

        #iterating through cat_list to check if category exists in particular row 
        for j in range(len(list_)):
            if list_[j] in m:
                cat_freq_dict[list_[j]] += 1
            else:
                pass
    if not cat_freq_dict:
        return None
    return cat_freq_dict.most_common(10)

# %% [markdown]
# Getting dictionary of actors who have acted in maximum number of movies, we will use previously created movie_df for this purpose.

# %%
top_10_maximum_occuring_dict = top_10_maximum_occuring(movie_df[~movie_df['cast'].isna()]['cast'])

# %%
# creating df out of above
top_10_maximum_occuring_movie_actor_df = pd.DataFrame(top_10_maximum_occuring_dict)

#renaming columns
top_10_maximum_occuring_movie_actor_df.rename(columns={0:'actors', 1:'number_of_movies'}, inplace=True)

# %%
# Chart - 4 visualization code
# creating barplot
sns.barplot(data=top_10_maximum_occuring_movie_actor_df, x='actors', y='number_of_movies')

#setting title
plt.title('Top 10 Actors who have acted in maximum number of Movies', fontsize=20)
plt.xlabel('Actors', fontsize=12)
plt.ylabel('Number of movies acted in', fontsize=10)

# setting xticklabels to 45
plt.xticks(rotation=15)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart to show top actors who have acted in maximum number of movies in dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Anupam Kher has acted in maximum number of movies, i.e, 38, followed by Om Puri, Shah Rukh Khan, Boman Irani and others.
# *  It is pretty clear that Indian actors have dominated this list with 9 out of 10 actors in top 10 most frequently occuring actors are Indian, with Kareena Kapoor being the only female to have place in this chart.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this might indicate which actors people want to view most and also what actors are in trend. This might help Producers, Recommendation Engineers and Movie enthusiasts to understand and select type to movies to watch, recommend and invest in.

# %% [markdown]
# #### Chart - 5 (**Actors who have acted in maximum number of TV Shows**)

# %% [markdown]
# Getting dictionary of actors who have acted in maximum number of movies, we will use previously created tv_show_df for this purpose.

# %%
top_10_maximum_occuring_tv_actor_dict = top_10_maximum_occuring(tv_show_df[~tv_show_df['cast'].isna()]['cast'])

# %%
# creating df out of above
top_10_maximum_occuring_tv_actor_df = pd.DataFrame(top_10_maximum_occuring_tv_actor_dict)

#renaming columns
top_10_maximum_occuring_tv_actor_df.rename(columns={0:'actors', 1:'number_of_tv_shows'}, inplace=True)

# %%
# Chart - 5 visualization code
# Chart - 5 visualization code
# creating barplot
sns.barplot(data=top_10_maximum_occuring_tv_actor_df, x='actors', y='number_of_tv_shows')

#setting title
plt.title('Top 10 Actors who have acted in maximum number of TV Shows', fontsize=20)
plt.xlabel('Actors', fontsize=12)
plt.ylabel('Number of TV Shows acted in', fontsize=10)

# setting xticklabels to 45
plt.xticks(rotation=15)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart to show top 10 casts who have worked in maximum number TV Shows in dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Like top 10 most frequently occuring actors list had Indian dominance, top 10 casts who have most number of TV Shows to them have Japanese Television Anime dominance.
# *   9 out of 10 cast names in this list are voice artists from Japanese Anime industry.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight can help search engines recommend anime lovers relevant content, also it can help anime creaters understand what voice artists are in demand.
#
# It can also help analysts and adverstisers understand where to focus on based upon what is being watched most on Netflix.

# %% [markdown]
# #### Chart - 6 ( **Top 10 Countries from Where Maximum Movies and TV Shows are produced**)

# %%
# checking values in Country column
df['country']
# Out:
# 0                                                  Brazil
# 1                                                  Mexico
# 2                                               Singapore
# 3                                           United States
# 4                                           United States
#                               ...
# 7782    Sweden, Czech Republic, United Kingdom, Denmar...
# 7783                                                India
# 7784                                                  NaN
# 7785                                            Australia
# 7786                United Kingdom, Canada, United States
# Name: country, Length: 7787, dtype: object

# %% [markdown]
# Since a lot of values in country column have more than 1 country, within them, I will set first country name as primary country.

# %%
# creating a sample country df to filter out null values in country column
country_df = df[~df['country'].isna()]

# setting first country name as country in country_df using lambda function
country_df['country'] = country_df['country'].apply(lambda x: x[:x.index(',')] if ',' in x else x)
# Out:
# <ipython-input-46-425eaec57eac>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_df['country'] = country_df['country'].apply(lambda x: x[:x.index(',')] if ',' in x else x)

# %%
# getting country wise number of movies and tv shows
country_wise = country_df.groupby('country')['type'].value_counts().unstack().reset_index().replace(np.nan,0).rename(index={'type':'index'})

country_wise['Movie'] = country_wise['Movie'].apply(lambda x: int(x))
country_wise['TV Show'] = country_wise['TV Show'].apply(lambda x: int(x))

country_wise
# Out:
# type       country  Movie  TV Show
# 0        Argentina     50       18
# 1        Australia     56       52
# 2          Austria      7        1
# 3       Bangladesh      2        0
# 4          Belarus      0        1
# ..             ...    ...      ...
# 76         Uruguay      8        1
# 77       Venezuela      2        0
# 78         Vietnam      5        0
# 79    West Germany      1        0
# 80        Zimbabwe      1        0
#
# [81 rows x 3 columns]

# %%
# Chart - 6 visualization code
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
fig.tight_layout()
plt.subplots_adjust(wspace=0.25)
# code to show top 10 countries with maximum number of movies
maximum_number_of_movie_countries = country_wise[['country','Movie']].sort_values(by='Movie', ascending=False).head(10)

# creating a barplot showing top 10 countries producing maximum number of movies
sns.barplot(data=maximum_number_of_movie_countries, x='country', y='Movie', ax=axs[0])
axs[0].set_title('Top 10 countries producing maximum number of movies', fontsize=10)
axs[0].set_xlabel('Countries')
axs[0].set_ylabel('Number of Movies Produced')
axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=90)

# code to show top 10 countries with maximum number of tv shows 
maximum_number_of_tv_show_countries = country_wise[['country','TV Show']].sort_values(by='TV Show', ascending=False).head(10)

# creating a barplot showing top 10 countries producing maximum number of TV Shows
sns.barplot(data=maximum_number_of_tv_show_countries, x='country', y='TV Show', ax=axs[1])
axs[1].set_title('Top 10 countries producing maximum number of TV Shows', fontsize=10)
axs[1].set_xlabel('Countries')
axs[1].set_ylabel('Number of TV Shows Produced')
axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation=90)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart to show top 10 movie producing countries as well as top 10 TV Show producing countries in the world.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   In Movie Production as well as TV Show production, USA is on Top list out of all countries in dataset, with more than 2000 movies and around 800 TV Shows to its name.
# *   In movie production USA is followed by India, United Kingdom, Canada, France, Spain, Egypt, Mexico, Turkey and Japan.
# *   Like USA, UK have prominent place in both lists as well, while it is on 3rd Position in movie production with around 300 movies, it has also produced around 300 TV Shows of all movies in our dataset.
# *   Other prominent countries in both the lists are India, Japan, Canada, Sapin and France.
# *   One can see that other than Japan no other east asian countries are in Top 10 movie list, but when it comes to TV Shows; Japan, South Korea and Taiwan are all there. Makes sense since Korean Dramas are getting popular all over the world.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7 ( **Number of TV shows and movies added over time** )

# %%
# creating a df filtering nan values and sorting it by date added
date_added_df = df[~df.isna()].sort_values(by='date_added')

# %%
# extracting required columns only
date_added_df = date_added_df.groupby(['date_added', 'type'], as_index=False)['title'].count()

# %%
# Chart - 7 visualization code
sns.set_style('dark')
plt.figure(figsize=(15,5))
# create a line chart showing the number of TV shows and movies added over time
sns.lineplot(data=date_added_df, x='date_added', y='title', hue='type')
plt.title('Number of TV shows and movies added over time')
plt.xlabel('Date Added')
plt.ylabel('Number of TV shows and movies')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart to show distribution in date_added column. As to when maximum number of movies and TV Shows were added since the starting of dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   It is kind of obvious that until 2016, not much movies and TV Shows were being added to Netflix database. It seems like since that huge spike in 2016, when a lot of TV Shows were added, trend picked up.
# *   Most of the TV Shows and movies were added between 2018 and 2020.
# *   More number of Movies tha TV Shows were added, explains why there are a lot more movies than TV Shows in data. However, since 2017 and ahead a lot of TV Shows were added too.
# *   Simple reason for more movies than TV Shows can be the fact that a single TV Show runs for a lot greater time than a movie.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8 ( **Release year distribution for tv shows and movies** )

# %%
# filtering nan out of data
release_year_df = df[~df.isna()].sort_values(by='release_year')

# extracting required columns only
release_year_df = release_year_df.groupby(['release_year', 'type'], as_index=False)['title'].count()

# %%
# Chart - 8 visualization code
# plotting a barchart to show release year distribution of released movies and TV Shows
sns.barplot(data = release_year_df, x='release_year', y='title', hue='type')

# setting title and x and y labels
plt.title('Release year distribution for tv shows and movies in database', fontsize=12)
plt.xlabel('Release Year')
plt.ylabel('Title Count')

# rotating xticks
plt.xticks(rotation=90)

# relocating position of legend
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This barchart showsrelease year distribution of released movies and TV Shows in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Most of the movies and TV Shows in dataset ranges from 90s to 2020.
# *  While some of the movies in data are from 90s and kept growing with each year since then, TV Shows in data are from 2002 and beyond only.
# *  This plot has exponential increase, that indicates that most of the movies and TV Shows added in the data were released in recent years only.
# *  Because TV Shows released only since 2002 are added, it can be another reason for them being less than number of movies.
# *  Not much data is available for 2021.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9 ( **Number of movies and TV Shows by each rating type** )

# %%
# creating a ratings df for our purpose
ratings_df = df[~df.isna()]

# getting count for each rating type
ratings_df = ratings_df.groupby(['rating', 'type'], as_index=False)['title'].count().sort_values(by='title', ascending=False)

# %%
# Chart - 9 visualization code
# creating a barplot to show count of TV Shows and Movies by each rating type
sns.barplot(data=ratings_df, x='rating', y='title', hue='type')
plt.title('Count of TV Shows and Movies by each rating type')
plt.xlabel('Ratings')
plt.ylabel('Count')
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows Count of TV Shows and Movies by each rating type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Maximum number of the TV Shows and Movies are rated TV-MA, meaning they are for mature audiences only.
# *   It is followed by TV-14 meaning they can't be watched by children below 14 years of age. They contain maturity and other content that can be unsuitable for children.
# *   That is followed by R rating which is also an adult category, children needs supervision of parents to watch these kind of movies.
# *   TV Shows are available in 5 categories only; Most of them are in category TV-MA and TV-14, followed by TV-PG (parental guidance is recommended; these programs may be unsuitable for younger children), and TV-Y7 and TV-Y (last two categories are suitable for children as well).

# %% [markdown]
# #### Chart - 10 **( Duration chart for movies and TV Shows )**

# %%
movie_df['duration'].nunique()
# Out:
# 201

# %%
# Chart - 10 visualization code
sns.set_style('dark')
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
fig.tight_layout()
plt.subplots_adjust(wspace=0.25)
# code to show top 10 durations in which most of the movies were made
movie_duration_df = pd.DataFrame(movie_df['duration'].value_counts().head(10)).reset_index().rename(columns={'index':'duration', 'duration':'movie_count'})

# creating a barplot showing top 10 durations in which most of the movies were made
sns.barplot(data=movie_duration_df, x='duration', y='movie_count', ax=axs[0])
axs[0].set_title('Distribution of movie counts for top 10 most occurring durations', fontsize=10)
axs[0].set_xlabel('duration')
axs[0].set_ylabel('Number of Movies')
axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=90)

# code to show top 10 countries with maximum number of tv shows 
tv_show_duration_df = pd.DataFrame(tv_show_df['duration'].value_counts()).reset_index().rename(columns={'index':'duration', 'duration':'tv_show_count'})

# creating a barplot showing top 10 countries producing maximum number of TV Shows
sns.barplot(data=tv_show_duration_df, x='duration', y='tv_show_count', ax=axs[1])
axs[1].set_title('Distribution of TV Show season counts', fontsize=10)
axs[1].set_xlabel('Duration')
axs[1].set_ylabel('Number of TV Shows')
axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation=90)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# These charts hows maximum duartion for movies and TV Shows in dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Most of the movies have duration of 90 - 98 minutes, something around 1 and half hours.
# *   A lot of TV Shows (around 1600) ran only for one season, some 400 for two seasons, and so on.
# *   A very few TV Shows went on to stream for more than 8 seasons.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11 **(Wordcloud showing most occuring genres)**

# %%
# Chart - 11 visualization code
from wordcloud import WordCloud

plt.figure(figsize=(10,15), facecolor='k')
# Convert the column to a single string
text = ' '.join(df['listed_in'].tolist())

# Create the wordcloud object
wordcloud = WordCloud(width = 1600, height = 800).generate(text)

# Display the wordcloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This wordcloud shows most frequently occuring genres in Netflix data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   TV Shows, International Movies, International TV, Dramas are some of the frequently occuring genres.
# *   Apart from them movies, comedies, action movies, adventure, romantic movies, etc, can be seen occurring frequently too, and are other important genres.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ###**Bivariate Analysis**

# %% [markdown]
# #### Chart - 12 **(Relation between date added and ratings)**

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Chart - 12 visualization code
df1 = df[~df.isna()]

# scatterplot analysing relation between date added and ratings
sns.scatterplot(data=df1, x='rating', y='date_added')
plt.title('Relation between date added and ratings')
plt.xlabel('rating')
plt.ylabel('Date added')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows relation between date added and rating in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Since, most of the data in the dataset were added only since 2014, it is pretty obvious that since beginning only mature rated contents were uploaded.
# *   While not since beginning but after 2014 and with growing popularity of platform, even family and teen contents were added.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13 (**Scatter plot reresenting relation between release date and countries**)

# %%
# Chart - 13 visualization code
sns.set_style('whitegrid')
plt.figure(figsize=(20,8))

# code showing Realation between release date and countries
sns.scatterplot(data=country_df, x='country', y='release_year', hue='type')

plt.title('Relation between release date and countries')
plt.xlabel('countries')
plt.ylabel('release_year')
plt.xticks(rotation=90)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This scatter plot shows relation between release date and countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Countries in top 10 most movie producing countries in data started producing movies and tv shows from as early as 1950s and 60s.
# *   Some of the movies produced by USA have their release date in 1940s!
# *   India too have been producing movies constantly since late 1950s and 1960s.
# *   East asian countries like Japan, South Korea, Taiwan and Hong Kongs have produced more TV Shows than movies, as per this dataset.
# *   Most of the movies and TV Shows in dataset for East Asian countries seems have released after 2000, except for Hong Kong which have been producing movies since 1970s
# *   TV Shows have gained traction since beginning of 21st century.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %% [markdown]
# Since, country and rating columns are categorical columns, using correlation directly does not makes sense here. So to find correlation between these two using frequency, we would crosstab function from pandas library.

# %% [markdown]
# "A crosstab, also known as a contingency table or cross tabulation, is a type of table used to display the relationship between two or more variables. It is typically used in statistics and data analysis to show the frequency or count of observations that fall into different categories for each variable. The rows of the table represent one variable, while the columns represent another variable. The intersection of a row and column represents the frequency or count of observations that fall into that combination of categories. For example, a crosstab could be used to show the number of customers who purchased a certain product, broken down by age group and gender."

# %%
# Correlation Heatmap visualization code
# setting figure parameters to be able to show all values in country column
plt.figure(figsize=(14,20))

# Create the cross-tabulation table
correlation_table = pd.crosstab(country_df['country'], country_df['rating'], normalize='index')

# using heatmap to show correlation between country or whether or not they are relared to ratings
sns.heatmap(correlation_table, annot=True, fmt='.2%', cmap='YlGnBu')
plt.title('Heatmap showing correlation between countries and ratings')
plt.ylabel('Countries')
plt.xlabel('ratings')
# Out:
# Text(0.5, 159.0, 'ratings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This heatmap shows correlation between countries and ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   It seems like there is correlation between ratings and countries for some values in both columns.
# *   Iran has 100 percent correlation with PG-13 ratings, same as Somalia and Bulgaria has 100% correlation with R rating, Singapore and Soviet Union has 100% correlation with TV-14 rating, Zimbwabwe has 100% correlation with TV-G rating, and a lot of contries like Combodia, Croatia, Guetemala, etc has 100% correlation with TV-MA ratings.
# *   A thing to mind here is that a lot of these countries have very less movies in the dataset, for example Somalia and Soviet Union has only movie to show, and it makes sense if they have 100% correlation with respective ratings.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# *    Null hypothesis (H0): The 'country' and 'rating' columns are independent
# *      Alternative hypothesis (H1): The 'country' and 'rating' columns are associated

# %% [markdown]
# Before performing statistical test, I want to remove those countries from test which have produced way too less movies to be considered significant for hypothesis testing.

# %%
# creating a copy of country df
country_df1 = country_df.copy()

# %%
# group the dataframe by the 'country' column
grouped = country_df1.groupby('country')

# filter out the countries that have less than 5 titles
country_df1 = grouped.filter(lambda x: len(x) >= 5)

# %% [markdown]
# The first line groups the dataframe by the 'country' column. This creates a GroupBy object, which you can then use to filter out the countries that have less than 5 titles.
#
# The second line filters out the countries that have less than 5 titles by using the filter method with a lambda function that checks the length of each group. The lambda function takes a group (x) as input and returns True if the group has more than or equal to 5 rows and False otherwise. The resulting df will not contain countries that have less than 5 titles.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# creating the contingency table
contingency_table = pd.crosstab(country_df1['country'], country_df1['rating'])

# %% [markdown]
# Performing Chi Square Test

# %%
from scipy.stats import chi2_contingency
# Perform Statistical Test to obtain P-Value

# Performing the chi-squared test of independence
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

# setting alpha
alpha = 0.05

# Comparing the p-value to the significance level

print(f'The p-value for the test is: {p_value}.')
print('.'*150)
if p_value < alpha:
    print("Reject the null hypothesis, there is an association between 'country' and 'rating'.")
else:
    print("Fail to reject the null hypothesis, there is no enough evidence to suggest an association between 'country' and 'rating'")
# Out:
# The p-value for the test is: 3.566836961514013e-243.
# ......................................................................................................................................................
# Reject the null hypothesis, there is an association between 'country' and 'rating'.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I have performed Chi Square test to obtain P-Values.
#
# The chi-squared test of independence is a statistical test that is used to determine if there is a significant association between two categorical variables. It is based on the chi-squared distribution and is commonly used to test if there is a relationship between two categorical variables in a contingency table.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# The chi-squared test of independence is used when the sample size is large. It works by comparing the observed frequencies in the contingency table to the expected frequencies if the two variables were independent. The test statistic, chi-squared, is calculated based on the difference between the observed and expected frequencies, and it follows a chi-squared distribution.
#
# The null hypothesis of the chi-squared test of independence is that the two variables are independent, and the alternative hypothesis is that there is an association between the two variables. If the calculated p-value is less than the significance level, we reject the null hypothesis and conclude that there is an association between the two variables. If the p-value is greater than the significance level, we fail to reject the null hypothesis and conclude that there is not enough evidence to suggest an association.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# *  Null hypothesis (H0): The 'director' and 'rating' columns are independent
# *  Alternative hypothesis (H1): The 'director' and 'rating' columns are associated

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import chi2_contingency

# create a contingency table with the count of each combination of rating and director
contingency_table2 = pd.crosstab(country_df['director'], country_df['rating'])

# perform the chi-squared test
chi2, p, dof, expected = chi2_contingency(contingency_table2)

# setting alpha
alpha = 0.5

# Comparing the p-value to the significance level
# print the p-value
print(f'The p-value for the test is: {p_value}')
print('.'*150)

if p_value < alpha:
    print("Reject the null hypothesis, there is an association between 'director' and 'rating'.")
else:
    print("Fail to reject the null hypothesis, there is no enough evidence to suggest an association between 'director' and 'rating'.")
# Out:
# The p-value for the test is: 1.4366285938649526e-13
# ......................................................................................................................................................
# Reject the null hypothesis, there is an association between 'director' and 'rating'.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I have performed Chi Square test to obtain P-Values.
#
# The chi-squared test of independence is a statistical test that is used to determine if there is a significant association between two categorical variables. It is based on the chi-squared distribution and is commonly used to test if there is a relationship between two categorical variables in a contingency table.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# I have performed Chi Square test to obtain P-Values.
#
# The chi-squared test of independence is a statistical test that is used to determine if there is a significant association between two categorical variables. It is based on the chi-squared distribution and is commonly used to test if there is a relationship between two categorical variables in a contingency table.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# While doing analysis it was observed that only after 2000s, a lot of TV Shows were added and before that there were less TV Shows and movies.
#
# So, here this hypothesis will be tasted if these two are related.

# %% [markdown]
# > Null hypothesis (H0): The 'release_year' and 'type' columns are independent.
#
#
# > Alternative hypothesis (H1): The 'release_year' and 'type' columns are associated.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import chi2_contingency

# create a contingency table with the count of each combination of rating and director
contingency_table3 = pd.crosstab(country_df['release_year'], country_df['type'])

# perform the chi-squared test
chi2, p, dof, expected = chi2_contingency(contingency_table3)

# setting alpha
alpha = 0.5

# Comparing the p-value to the significance level
# print the p-value
print(f'The p-value for the test is: {p_value}')
print('.'*150)

if p_value < alpha:
    print("Reject the null hypothesis, there is an association between 'release_year' and 'type'.")
else:
    print("Fail to reject the null hypothesis, there is no enough evidence to suggest an association between 'release_year' and 'type'.")
# Out:
# The p-value for the test is: 1.4366285938649526e-13
# ......................................................................................................................................................
# Reject the null hypothesis, there is an association between 'release_year' and 'type'.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# The chi-squared test of independence is a statistical test that is used to determine if there is a significant association between two categorical variables. It is based on the chi-squared distribution and is commonly used to test if there is a relationship between two categorical variables in a contingency table.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
df.shape
# Out:
# (7787, 12)

# %%
#getting all the missing values 
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
# percentage of null values in each column
for i in df.columns:
  print(f"Percentage of null values in '{i}' columns is {round((df[i].isna().sum()/df.shape[0])*100,2)}%.")
  print("~"*200)
# Out:
# Percentage of null values in 'show_id' columns is 0.0%.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Percentage of null values in 'type' columns is 0.0%.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Percentage of null values in 'title' columns is 0.0%.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Percentage of null values in 'director' columns is 30.68%.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Percentage of null values in 'cast' columns is 9.22%.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Percentage of null values in 'country' columns is 6.51%.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Percentage of null values in 'date_added' columns is 0.13%.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Percentage of null values in 'release_year' columns is 0.0%.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Percentage of null values in 'rating' columns is 0.09%.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Percentage of null values in 'duration' columns is 0.0%.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Percentage of null values in 'listed_in' columns is 0.0%.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Percentage of null values in 'description' columns is 0.0%.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# Four columns have null values in them:
#
# 1. director (apprx 31% null values)
# 2. cast (apprx 9.22% null values)
# 3. country (apprx 7% null values)
# 4. date_added(about 0.13% null values)
# 5. rating (0.09%)

# %%
# creating a copy of df just for safety
df2 = df.copy()

# %%
# Handling Missing Values & Missing Value Imputation
df2.fillna(' ', inplace=True)

# %%
# checking null values in df2 column again
df2.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# I simply replaced null values with empty strings.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Since, almost all the columns are categorical columns, I will not go ahead with outlier detection and treatment

# %% [markdown]
# ### 3. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features
# Combining all the clustering attributes into a single column

df2['clustering_attributes'] = (df2['director'] + ' ' + 
                                df2['cast'] +' ' + 
                                df2['country'] +' ' + 
                                df2['listed_in'] +' ' + 
                                df2['description'])

# %%
df2['clustering_attributes'][20]
# Out:
# 'Onir Geetanjali Thapa, Zain Khan Durrani, Shray Rai Tiwari, Mona Ambegaonkar, Chandreyee Ghosh, Barun Chanda, Saheb Bhattacharjee, Shefali Chauhan India Dramas, Independent Movies, International Movies After accidentally connecting over the Internet, two strangers form a tight friendship – not knowing they already share a bond.'

# %% [markdown]
# Here, I have added all the required features into a single column.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %%
# installing contractions
# !pip install contractions
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii
#   Downloading anyascii-0.3.1-py3-none-any.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 KB 17.8 MB/s eta 0:00:00
# Collecting pyahocorasick
#   Downloading pyahocorasick-2.0.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.5/104.5 KB 11.7 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.1 contractions-0.1.73 pyahocorasick-2.0.0 textsearch-0.0.24

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction
import contractions
import re

# Define a function to expand contractions
def expand_contractions(text, contraction_mapping=contractions.contractions_dict):
    # Create a regular expression pattern to match contractions
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    # Define a function to expand the matched contraction
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        # Get the expanded form of the contraction
        expanded_contraction = contraction_mapping.get(match) or contraction_mapping.get(match.lower())
        if expanded_contraction:
            expanded_contraction = first_char + expanded_contraction[1:]
        return expanded_contraction
    # Substitute the contractions with their expanded form
    expanded_text = contractions_pattern.sub(expand_match, text)
    # Remove the apostrophe
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text


df2['clustering_attributes'] = df2['clustering_attributes'].apply(expand_contractions)

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing
df2['clustering_attributes'] = df2['clustering_attributes'].str.lower()

# %% [markdown]
# #### 3. Removing Punctuations

# %%
import string
# function to remove punctuations
def remove_punctuation(text):
    '''a function for removing punctuation'''
    translator = str.maketrans('', '', string.punctuation)
    # return the text stripped of punctuation marks
    return text.translate(translator)

# %%
# Remove Punctuations
df2['clustering_attributes'] = df2['clustering_attributes'].apply(remove_punctuation)

# %%
df2['clustering_attributes'][20]
# Out:
# 'onir geetanjali thapa zain khan durrani shray rai tiwari mona ambegaonkar chandreyee ghosh barun chanda saheb bhattacharjee shefali chauhan india dramas independent movies international movies after accidentally connecting over the internet two strangers form a tight friendship – not knowing they already share a bond'

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits
import unicodedata
# function to remove non-ascii characters

def remove_non_ascii(words):
    """Function to remove non-ASCII characters"""
    new_words = []
    for word in words:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    return new_words




# remove non-ascii characters
df2['clustering_attributes'] = remove_non_ascii(df2['clustering_attributes'])

# %%
# remove words and digits contain digits
df2['clustering_attributes'] = df2['clustering_attributes'].str.replace(r'\b\d+\w+|\w+\d+\b','')

# remove URLs from the 'clustering_attributes' column
df2['clustering_attributes'] = df2['clustering_attributes'].str.replace(r'(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w \.-]*)*\/?','')
# Out:
# <ipython-input-139-45986885a95b>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['clustering_attributes'] = df2['clustering_attributes'].str.replace(r'\b\d+\w+|\w+\d+\b','')
# <ipython-input-139-45986885a95b>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['clustering_attributes'] = df2['clustering_attributes'].str.replace(r'(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w \.-]*)*\/?','')

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# extracting the stopwords from nltk library
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
sw = stopwords.words('english')
# displaying the stopwords
np.array(sw)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# array(['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you',
#        "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself',
#        'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her',
#        'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them',
#        'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom',
#        'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are',
#        'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had',
#        'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and',
#        'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at',
#        'by', 'for', 'with', 'about', 'against', 'between', 'into',
#        'through', 'during', 'before', 'after', 'above', 'below', 'to',
#        'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under',
#        'again', 'further', 'then', 'once', 'here', 'there', 'when',
#        'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
#        'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own',
#        'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will',
#        'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll',
#        'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn',
#        "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't",
#        'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma',
#        'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't",
#        'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't",
#        'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"],
#       dtype='<U10')

# %%
# function to remove stop words
def stopwords(text):
    '''a function for removing the stopword'''
    # removing the stop words and lowercasing the selected words
    text = [word.lower() for word in text.split() if word.lower() not in sw]
    # joining the list of words with space separator
    return " ".join(text)

# %%
# Removing stop words
df2['clustering_attributes'] = df2['clustering_attributes'].apply(stopwords)

# %%
# Remove White spaces
# remove leading and trailing white spaces from the 'clustering_attributes' column
df2['clustering_attributes'] = df2['clustering_attributes'].str.strip()

# %% [markdown]
# #### 6. Rephrase Text

# %% [markdown]
# Since, rephrasing Text was not showing any meaningful result, I ommitted that.

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization
#installing punkt
nltk.download('punkt')


     
# converting test into columns into tokens
df2['clustering_attributes'] = df2['clustering_attributes'].apply(lambda x: " ".join(nltk.word_tokenize(x)))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# #### 8. Text Normalization

# %%
import nltk
nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

from nltk.stem import WordNetLemmatizer
# function to lemmatize the corpus
def lemmatize_verbs(words):
    """Lemmatize verbs in list of tokenized words"""
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word, pos='v')
        lemmas.append(lemma)
    return lemmas

# %%
# Lemmatization
df2['clustering_attributes'] = lemmatize_verbs(df2['clustering_attributes'])

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# I have used WordNet lemmatizer for text normalisation. Lemmatization is the process of reducing words to their base or root form, known as the lemma. It is similar to stemming, which also reduces words to their base form, but lemmatization is more sophisticated and based on the WordNet corpus which contains a large set of words and their relationships.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# import the required modules
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet

# download the required resources
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

# define a function to get the part of speech of a word
def get_wordnet_pos(tag):
    """
    This function takes a POS tag as input and returns the corresponding WordNet POS tag
    """
    if tag.startswith('J'):
        return wordnet.ADJ  # adjective
    elif tag.startswith('V'):
        return wordnet.VERB  # verb
    elif tag.startswith('N'):
        return wordnet.NOUN  # noun
    elif tag.startswith('R'):
        return wordnet.ADV  # adverb
    else:
        return None
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# create a new column 'Lemmatized_Text'
df2['Lemmatized_Text'] = ""

for i, row in df2.iterrows():
    text = row['clustering_attributes']
    # tokenize the text
    tokens = word_tokenize(text)
    lemmatized_tokens = []
    for word, tag in nltk.pos_tag(tokens):
        wn_tag = get_wordnet_pos(tag)
        if wn_tag is None:
            lemmatized_tokens.append(word)
            continue
        synsets = wordnet.synsets(word, pos=wn_tag)
        if len(synsets) == 0:
            lemmatized_tokens.append(word)
            continue
        lemma = synsets[0].lemmas()[0]
        lemmatized_tokens.append(lemma.name())
    df2.at[i, 'Lemmatized_Text'] = " ".join(lemmatized_tokens)

# %%
#POS Taging
# create a new column 'Lemmatized_Text'
df2['Lemmatized_Text'] = ""

for i, row in df2.iterrows():
    text = row['clustering_attributes']
    # tokenize the text
    tokens = word_tokenize(text)
    lemmatized_tokens = []
    for word, tag in nltk.pos_tag(tokens):
        wn_tag = get_wordnet_pos(tag)
        if wn_tag is None:
            lemmatized_tokens.append(word)
            continue
        synsets = wordnet.synsets(word, pos=wn_tag)
        if len(synsets) == 0:
            lemmatized_tokens.append(word)
            continue
        lemma = synsets[0].lemmas()[0]
        lemmatized_tokens.append(lemma.name())
    df2.at[i, 'Lemmatized_Text'] = " ".join(lemmatized_tokens)

# %%
df2['Lemmatized_Text'][20]
# Out:
# 'onir geetanjali thapa zain khan durrani shray rai tiwari Anglesey ambegaonkar chandreyee ghosh barun chanda saheb bhattacharjee shefali chauhan india play independent movie international movie by_chance connect internet two stranger form tight friendship know already share chemical_bond'

# %% [markdown]
# Here, instead of understanding that two people share some kind of human bond, POS tagging has marked it as chemical bond, and that's why I would be avoiding it for further purpose.

# %%
df2.drop(columns=['Lemmatized_Text'], axis=1, inplace=True)

# %% [markdown]
# #### 10. Text Vectorization

# %% [markdown]
# We can vectorize the corpus using TFIDF vectorizer, where TFIDF stands for - Term Frequency Inverse Document Frequency.

# %%
# clustering tokens saved in a variable
clustering_data = df2['clustering_attributes']

# %%
# Vectorizing Text
from sklearn.feature_extraction.text import TfidfVectorizer

# create the vectorizer
vectorizer = TfidfVectorizer(stop_words='english', lowercase=False, max_features=20000)

# fit and transform the vectorizer to the documents
X = vectorizer.fit_transform(clustering_data)

# %%
X
# Out:
# <7787x20000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 232089 stored elements in Compressed Sparse Row format>

# %%
# Shape of X
X.shape
# Out:
# (7787, 20000)

# %%
# data type of vector
type(X)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
# convert X into array form for clustering
X = X.toarray()

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Tfidf Vectorizer has been used for vactorization in this case. TF-IDF is a way to quantify the importance of a word in a document within a collection of documents (also known as a corpus). The idea behind TF-IDF is that words that occur frequently in a document are important, but words that occur frequently in many documents are not as importan

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %% [markdown]
# Data transformation is not required in this case.

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# Data Scaling is not required.

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# * We can use PCA (Principal component Analysis) to reduce the dimensionality of data.

# %%
# DImensionality Reduction (If needed)
from sklearn.decomposition import PCA
# using PCA to reduce dimensionality
pca = PCA(random_state=68)
pca.fit(X)
# Out:
# PCA(random_state=68)

# %%
# Explained variance for different number of components
plt.figure(figsize=(10,5))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.title('PCA - Cumulative explained variance vs number of components')
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
# Out:
# Text(0, 0.5, 'cumulative explained variance')

# %% [markdown]
# *    We find that 100% of the variance is explained by about ~7500 components.
# *    Also, more than 80% of the variance is explained just by 4000 components.
# *   Hence to simplify the model, and reduce dimensionality, we can take the top 4000 components, which will still be able to capture more than 80% of variance.

# %%
# reducing the dimensions to 4000 using pca
pca = PCA(n_components=4000,random_state=68)
pca.fit(X)
# Out:
# PCA(n_components=4000, random_state=68)

# %%
# transformed features
x_pca = pca.transform(X)

# %%
# shape of transformed vectors
x_pca.shape
# Out:
# (7787, 4000)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# I have used PCA(Principal Component Analysis) for dimensionality reduction. PCA is commonly used to reduce the dimensionality of high-dimensional data. This can make it easier to visualize and analyze the data, as well as reduce the computational cost of some machine learning algorithms.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Not required, since clustering will be done.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# No need to handled imbalancenness as its a clusturing project.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation (Clustering)***

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# Building clusters using the K-means clustering algorithm.
#
# Visualizing the elbow curve and Silhouette score to decide on the optimal number of clusters for K-means clustering algorithm.

# %%
# Elbow method to find the optimal value of k
wcss=[]
for i in range(1,31):
  kmeans = KMeans(n_clusters=i,init='k-means++',random_state=33)
  kmeans.fit(x_pca)
  wcss_iter = kmeans.inertia_
  wcss.append(wcss_iter)

number_clusters = range(1,31)
plt.figure(figsize=(10,5))
plt.plot(number_clusters,wcss)
plt.title('The Elbow Method - KMeans clustering')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
from sklearn.metrics import silhouette_score



# Plotting Silhouette score for different umber of clusters
range_n_clusters = range(2,31)
silhouette_avg = []
for num_clusters in range_n_clusters:
  # initialize kmeans
  kmeans = KMeans(n_clusters=num_clusters,init='k-means++',random_state=33)
  kmeans.fit(x_pca)
  cluster_labels = kmeans.labels_
 
  # silhouette score
  silhouette_avg.append(silhouette_score(x_pca, cluster_labels))

plt.figure(figsize=(10,5))
plt.plot(range_n_clusters,silhouette_avg)
plt.xlabel('Values of K') 
plt.ylabel('Silhouette score')
plt.title('Silhouette analysis For Optimal k - KMeans clustering')
plt.show()

# %% [markdown]
# **The highest Silhouette score is obtained for 6 clusters.**

# %% [markdown]
# Building 6 clusters using the k-means clustering algorithm:

# %% [markdown]
# ### ML Model - 1**(K-Means Clustering)**

# %%
# ML Model - 1 Implementation
# Clustering the data into 19 clusters
kmeans = KMeans(n_clusters=6,init='k-means++',random_state=68)

# Fit the Algorithm
kmeans.fit(x_pca)
# Out:
# KMeans(n_clusters=6, random_state=68)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %% [markdown]
# K-means is a popular clustering algorithm that groups similar data points together. The goal of the algorithm is to partition a dataset into k clusters, where each cluster is defined by the mean of the data points in that cluster.
#
# The k-means algorithm works in the following steps:
#
# *    Initialize k centroids at random locations in the feature space.
# *    Assign each data point to the cluster whose centroid is closest to it.
# *    Re-compute the centroid of each cluster as the mean of all data points in that cluster.
# *    Repeat steps 2 and 3 until the cluster assignments no longer change or a maximum number of iterations is reached.
#
# The number of clusters, k, is a user-specified parameter and it should be chosen based on domain knowledge or through trial and error.
#
# One of the advantages of k-means is that it is easy to implement and computationally efficient, especially for large datasets. However, it has some limitations. For example, it assumes that the clusters are spherical and have similar variances, which may not be the case for all datasets. Additionally, it is sensitive to the initial configuration of the clusters, so it is recommended to run the algorithm multiple times with different initial configurations and choose the one that gives the best results.
#
# Another limitation is that it requires the user to specify the number of clusters, which may not be known in advance.
#
# In summary, k-means is a simple, efficient and widely used clustering algorithm that tries to partition the data into k clusters based on the mean of the data points in each cluster. It could be useful when the number of clusters is known in advance or when the data has spherical clusters with similar variances.

# %%
# Visualizing evaluation Metric Score chart

# Evaluation metrics - distortion, Silhouette score
kmeans_distortion = kmeans.inertia_
kmeans_silhouette_score = silhouette_score(x_pca, kmeans.labels_)

print((kmeans_distortion,kmeans_silhouette_score))
# Out:
# (6375.4713110522, 0.0047706349460758714)

# %%
# Adding a kmeans cluster number attribute
df2['kmeans_cluster'] = kmeans.labels_

# %%
# Number of movies and tv shows in each cluster
plt.figure(figsize=(10,5))
q = sns.countplot(x='kmeans_cluster',data=df2, hue='type')
plt.title('Number of movies and TV shows in each cluster - Kmeans Clustering')
plt.show()

# %%
# Building a wordcloud for the movie descriptions
def kmeans_worldcloud(cluster_num):
  comment_words = ''
  stopwords = set(sw)

  # iterate through the csv file
  for val in df2[df2['kmeans_cluster']==cluster_num].description.values:
      
      # typecaste each val to string
      val = str(val)

      # split the value
      tokens = val.split()
      
      # Converts each token into lowercase
      for i in range(len(tokens)):
          tokens[i] = tokens[i].lower()
      
      comment_words += " ".join(tokens)+" "

  wordcloud = WordCloud(width = 700, height = 700,
                  background_color ='white',
                  stopwords = stopwords,
                  min_font_size = 10).generate(comment_words)


  # plot the WordCloud image                      
  plt.figure(figsize = (10,5), facecolor = None)
  plt.imshow(wordcloud)
  plt.axis("off")
  plt.tight_layout(pad = 0)

# %%
# Wordcloud for clusters
for i in range(6):
  kmeans_worldcloud(i)

# %% [markdown]
# ### ML Model - 2 **(Hierarchical clustering)**

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
